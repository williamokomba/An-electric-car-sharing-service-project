# %% [markdown]
# <a href="https://colab.research.google.com/github/williamokomba/An-electric-car-sharing-service-project/blob/master/Data_Cleaning_%26_EDA_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Data cleaning & EDA**

# %%
#importing the required libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ##**Maurine csv files**

# %%
#1 file
per_county_df = pd.read_csv("/content/Cases_Per_County.csv")
per_county_df
# Out:
#                                             Unnamed: 0  ...  Nairobi
# 0                    Newcounty_cases 8th-November-2021  ...        0
# 1                    Newcounty_cases 7th-November-2021  ...        0
# 2                    Newcounty_cases 6th-November-2021  ...        0
# 3                    Newcounty_cases 5th-November-2021  ...        0
# 4                    Newcounty_cases 4th-November-2021  ...        0
# ..                                                 ...  ...      ...
# 505  Newcounty_cases Science/Covid-data-by-age/scan...  ...        0
# 506  Newcounty_cases Science/Covid-data-by-age/scan...  ...        0
# 507  Newcounty_cases Science/Covid-data-by-age/scan...  ...        0
# 508  Newcounty_cases Science/Covid-data-by-age/scan...  ...        0
# 509  Newcounty_cases Science/Covid-data-by-age/scan...  ...        0
#
# [510 rows x 48 columns]

# %%
per_county_df["Unnamed: 0"].unique()
# Out:
# array(['Newcounty_cases 8th-November-2021',
#        'Newcounty_cases 7th-November-2021',
#        'Newcounty_cases 6th-November-2021',
#        'Newcounty_cases 5th-November-2021',
#        'Newcounty_cases 4th-November-2021',
#        'Newcounty_cases 3rd-November-2021',
#        'Newcounty_cases 2nd-November-2021',
#        'Newcounty_cases 1st-November-2021',
#        'Newcounty_cases 31st-October-2021',
#        'Newcounty_cases 30th-October-2021',
#        'Newcounty_cases 29th-October-2021',
#        'Newcounty_cases 28th-October-2021',
#        'Newcounty_cases 27th-October-2021',
#        'Newcounty_cases 26th-October-2021',
#        'Newcounty_cases 25th-October-2021',
#        'Newcounty_cases 24th-October-2021',
#        'Newcounty_cases 23rd-October-2021',
#        'Newcounty_cases 22nd-October-2021',
#        'Newcounty_cases 21th-October-2021',
#        'Newcounty_cases 20th-October-2021',
#        'Newcounty_cases 19th-October-2021',
# ...

# %%
#2 file
fatality_df = pd.read_csv("/content/fatalities.csv")
fatality_df.head()
# Out:
#   Age_group  ...  Fatalities 5th-August-2021
# 0       0-9  ...                         NaN
# 1     10-19  ...                         NaN
# 2     20-29  ...                         NaN
# 3     30-39  ...                         NaN
# 4     40-49  ...                         NaN
#
# [5 rows x 91 columns]

# %%
fatality_df.columns
# Out:
# Index(['Age_group', 'Fatalities 2nd-November-2021',
#        'Fatalities 1st-November-2021', 'Fatalities 31st-October-2021',
#        'Fatalities 30th-October-2021', 'Fatalities 29th-October-2021',
#        'Fatalities 28th-October-2021', 'Fatalities 27th-October-2021',
#        'Fatalities 26th-October-2021', 'Fatalities 25th-October-2021',
#        'Fatalities 24th-October-2021', 'Fatalities 23rd-October-2021',
#        'Fatalities 22nd-October-2021', 'Fatalities 21th-October-2021',
#        'Fatalities 20th-October-2021', 'Fatalities 19th-October-2021',
#        'Fatalities 18th-October-2021', 'Fatalities 17th-October-2021',
#        'Fatalities 16th-October-2021', 'Fatalities 15th-October-2021',
#        'Fatalities 14th-October-2021', 'Fatalities 13th-October-2021',
#        'Fatalities 12th-October-2021', 'Fatalities 10th-October-2021',
#        'Fatalities 9th-October-2021', 'Fatalities 8th-October-2021',
#        'Fatalities 7th-October-2021', 'Fatalities 6th-October-2021',
# ...

# %%
#3 file
incomp_fal1= pd.read_csv(r"/content/Incomplete_Fatalities_by_Age - Incomplete_Fatalities_by_Age.csv")
incomp_fal1.head()
# Out:
#   Age_group  ...  Fatalities 23rd-June-2021
# 0       0-9  ...                          0
# 1     10-19  ...                          1
# 2     20-29  ...                          0
# 3     30-39  ...                          3
# 4     40-49  ...                          1
#
# [5 rows x 511 columns]

# %%
#3 file
incomp_fal2 = pd.read_csv("/content/Incomplete_Fatalities_by_Age.csv")
incomp_fal2.head()
# Out:
#   Age_group  ...  Fatalities 23rd-June-2021
# 0       0-9  ...                          0
# 1     10-19  ...                          1
# 2     20-29  ...                          0
# 3     30-39  ...                          3
# 4     40-49  ...                          1
#
# [5 rows x 511 columns]

# %%
#4 file
incomp_newcas1= pd.read_csv("/content/Incomplete_New_Cases_By_Age - Incomplete_New_Cases_By_Age.csv")
incomp_newcas1.head()
# Out:
#   Age_group  ...  New_cases 23rd-June-2021
# 0       0-9  ...                        16
# 1     10-19  ...                        27
# 2     20-29  ...                        89
# 3     30-39  ...                       136
# 4     40-49  ...                       103
#
# [5 rows x 511 columns]

# %%
#5 file
incomp_newcas2= pd.read_csv("/content/Incomplete_New_Cases_By_Age.csv")
incomp_newcas2.head()
# Out:
#   Age_group  ...  New_cases 23rd-June-2021
# 0       0-9  ...                        16
# 1     10-19  ...                        27
# 2     20-29  ...                        89
# 3     30-39  ...                       136
# 4     40-49  ...                       103
#
# [5 rows x 511 columns]

# %%
#6 file
cases_age = pd.read_csv("/content/cases_by_age.csv")
cases_age.head()
# Out:
#   Age_group  ...  New_cases 5th-August-2021
# 0       0-9  ...                        NaN
# 1     10-19  ...                        NaN
# 2     20-29  ...                        NaN
# 3     30-39  ...                        NaN
# 4     40-49  ...                        NaN
#
# [5 rows x 91 columns]

# %% [markdown]
# ##**Emmanuel datasets**

# %%
clean_df = pd.read_csv("/content/clean_pdf.csv")
clean_df.head()
# Out:
#        Unnamed: 0  20 march 2020  ...  12 march 2020  july 18 2020
# 0         Baringo              0  ...              0             0
# 1           Bomet              0  ...              0             0
# 2         Bungoma              0  ...              0             1
# 3           Busia              0  ...              0            15
# 4  ElgeyoMarakwet              0  ...              0             0
#
# [5 rows x 179 columns]

# %%
data2 = pd.read_csv("/content/clean_pdf_log_file.csv")
data2
# Out:
#      Unnamed: 0  ...                  1
# 0             0  ...      20 march 2020
# 1             1  ...       1 april 2020
# 2             2  ...       july 16 2020
# 3             3  ...   december 13 2020
# 4             4  ...       april 8 2021
# ..          ...  ...                ...
# 173         173  ...   september 9 2021
# 174         174  ...  september 13 2021
# 175         175  ...       july 19 2020
# 176         176  ...      12 march 2020
# 177         177  ...       july 18 2020
#
# [178 rows x 3 columns]

# %% [markdown]
# ## **Scanned files**

# %%
#1. loading scanned dataset
scanned_df = pd.read_csv("/content/scanned_pdf.csv")
#
#previewing the top 5 rows;
scanned_df.head()
# Out:
#        Unnamed: 0  september 11 2020  ...  december 3 2020  september 18 2020
# 0         Baringo                  0  ...                0                  1
# 1           Bomet                  2  ...               11                  0
# 2         Bungoma                  1  ...               19                  0
# 3           Busia                  2  ...                7                  0
# 4  ElgeyoMarakwet                  0  ...                0                  1
#
# [5 rows x 326 columns]

# %%
#checking the last 5 rows
scanned_df.tail()
# Out:
#     Unnamed: 0  september 11 2020  ...  december 3 2020  september 18 2020
# 42     Turkana                  0  ...                2                  0
# 43  UasinGishu                 13  ...               14                  6
# 44      Vihiga                  0  ...                0                  0
# 45       Wajir                  0  ...                0                  0
# 46   WestPokot                  0  ...                0                  0
#
# [5 rows x 326 columns]

# %%
#checking the shape

records1=scanned_df.shape[1]
variables1 = scanned_df.shape[0]
#
print(r"The dataset contains {} records and {} variables".format(records1, variables1))
# Out:
# The dataset contains 326 records and 47 variables

# %%
#checking dataset information
scanned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Columns: 326 entries, Unnamed: 0 to september 18 2020
# dtypes: int64(325), object(1)
# memory usage: 119.8+ KB

# %%
# 2. loading the scanned dataset description
scanned_des_df =pd.read_csv("/content/scanned_pdf_log_file.csv")
#
#previewing the top 5 rows
scanned_des_df[:10]
# Out:
#    Unnamed: 0  ...                  1
# 0           0  ...  september 11 2020
# 1           1  ...    january 16 2021
# 2           2  ...    february 7 2021
# 3           3  ...    february 9 2021
# 4           4  ...      april 12 2021
# 5           5  ...  september 16 2020
# 6           6  ...      april 18 2021
# 7           7  ...     18 august 2020
# 8           8  ...          june 2020
# 9           9  ...    december 9 2020
#
# [10 rows x 3 columns]

# %%
#Making a copy for data cleaning so that we don't intefere with the original dataset.
scanned_df1 = scanned_df.copy(deep=True)

# %%
scanned_df1.rename(columns={"Unnamed: 0": "County", "june 2020":"1 june 2020", "no date":"14 april 2020",
"april 2020 NO1": "18 april 2020", "april 2020 NO2": "20 april 2020", "april 2020 NO3":"21 april 2020",
"april 2020 NO4": "22 april 2020", "april 2020 NO5":"23 april 2020", "april 2020 NO6":"24 april 2020",
"april 2020 NO7": "26 april 2020", "april 2020 NO8":"29 april 2020", "april 2020 NO9": "30 april 2020",
"may 2020": "2 may 2020","may 2020 NO10":"7 may 2020","may 2020 NO11":"9 may 2020",
"may 2020 NO12": "11 may 2020", "may 2020 NO13": "12 may 2020", "may 2020 NO14": "15 may 2020",
"may 2020 NO15": "20 april 2020", "may 2020 NO16": "27 may 2020", "may 2020 NO17": "29 april 2020",
"may 2020 NO18":"30 may 2020", "no date NO19": "31 may 2020", "june 2020 NO20": "2 june 2020",
"june 2020 NO21": "9 june 2020", "june 2020 NO22":"11 june 2020", "april 2020 NO23":"9 april 2020",
"march 2020": "4 march 2020", "july":"1 july 2020", "july NO24":"10 july 2020", "july 2020 NO25":"4 july 2020"

}, inplace=True)

#preview
scanned_df1.head()
# Out:
#            County  september 11 2020  ...  december 3 2020  september 18 2020
# 0         Baringo                  0  ...                0                  1
# 1           Bomet                  2  ...               11                  0
# 2         Bungoma                  1  ...               19                  0
# 3           Busia                  2  ...                7                  0
# 4  ElgeyoMarakwet                  0  ...                0                  1
#
# [5 rows x 326 columns]

# %%
scanned_df1.columns[:11]
# Out:
# Index(['Unnamed: 0', 'september 11 2020', 'january 16 2021', 'february 7 2021',
#        'february 9 2021', 'april 12 2021', 'september 16 2020',
#        'april 18 2021', '18 august 2020', 'june 2020', 'december 9 2020'],
#       dtype='object')

# %%
scanned_df1.columns[0:11]
# Out:
# Index(['Unnamed: 0', 'september 11 2020', 'january 16 2021', 'february 7 2021',
#        'february 9 2021', 'april 12 2021', 'september 16 2020',
#        'april 18 2021', '18 august 2020', 'june 2020', 'december 9 2020'],
#       dtype='object')
